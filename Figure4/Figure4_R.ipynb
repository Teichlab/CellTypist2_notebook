# %% [markdown]
# # This notebook reproduces the main results in Figure 4 and its associated Supplementary Figures.

# %%
library(Seurat)
library(SeuratWrappers)
library(harmony)
library(batchelor)
# Out:
# Attaching SeuratObject
#
# Loading required package: Rcpp
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays

# %% [markdown]
# Load the Seurat object.

# %%
immune <- readRDS('Immune_benchmark.RDS')
immune
# Out:
# An object of class Seurat
# 1740 features across 417866 samples within 1 assay
# Active assay: RNA (1740 features, 0 variable features)
#  1 dimensional reduction calculated: pca

# %% [markdown]
# Counts, normalised expression, and scaled expression are in `$RNA@counts`, `$RNA@data`, and `$RNA@scale.data`, respectively. Only HVGs (n = 1740) are kept for each slot. `$pca@cell.embeddings` is calculated directly based on scaled expression.

# %%
dim(immune)
# Out:
# [1]   1740 417866

# %%
head(immune$pca@cell.embeddings)
# Out:
#                                             PC_1     PC_2       PC_3
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 5.416077 -6.0498362 10.968814
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 7.057451 -3.0223880 10.836546
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 4.386515 -4.7069697  8.621740
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 6.217113 -1.1354387  5.774805
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 6.166337 -0.1343326  6.836470
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 7.031715 -4.7782269 10.405839
#                                             PC_4     PC_5        PC_6
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 9.143096  1.86473703 19.38028
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 7.326011  1.52235210 20.29700
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 6.324101 -0.26655400 14.55744
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 4.606223 -0.42209879 10.48193
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 3.671364 -0.08204001 10.36803
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 8.502954  1.51264346 19.08922
#                                             PC_7       PC_8        PC_9
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19  -6.667823 -4.06973362  3.454499
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 -10.833186  0.07486933 10.856373
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19  -7.349488 -0.10442275 12.203967
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19  -7.384690  2.89863539 14.715957
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19  -7.498146  3.81424642 14.093477
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19  -8.479601 -2.14026594 10.629246
#                                             PC_10     ⋯ PC_41      PC_42
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19  7.794345 ⋯ -3.4528303 -2.185286
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 18.561970 ⋯  0.5812054 -3.173053
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 14.867605 ⋯ -6.7907605 -4.453097
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 21.433641 ⋯ -2.3959765 -3.820570
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 22.637327 ⋯ -2.4594655 -4.993604
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 16.902018 ⋯ -6.1696877 -1.815609
#                                             PC_43    PC_44      PC_45
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 1.380609 -2.1336651  0.74454695
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 2.312178  0.1333792  0.55594981
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 2.546577 -1.8103009 -1.97028804
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 2.024290  0.3368653 -1.88660371
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 3.387558 -2.1972404 -1.68626940
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 1.412498 -2.9124920  0.07820153
#                                             PC_46      PC_47      PC_48
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 -0.4717946  1.2613487  1.1680659
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19  1.5963440 -0.4441859  0.7843529
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19  1.5208590  3.8420572 -0.5395530
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19  3.9220629  1.0426496 -1.3027308
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19  3.2642035  0.9631574 -1.9976892
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19  1.6690991  1.4457631  0.5992208
#                                             PC_49      PC_50
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19  1.6899846  0.07921237
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19  0.3136022  0.81404877
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19  0.2817632  1.42735469
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19  0.5401683  1.19695425
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 -0.2863128  1.71254468
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19  2.4982767 -0.51347858

# %%
head(immune[[]])
# Out:
#                                             Harmonised_broad_type
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 Mast cells
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 Mast cells
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 Mast cells
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 Mast cells
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 Mast cells
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 Mast cells
#                                             Harmonised_detailed_type
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 Mast cells
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 Mast cells
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 Mast cells
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 Mast cells
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 Mast cells
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 Mast cells
#                                             Label_from_original_study Tissue
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 Mast cell                 Liver
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 Mast cell                 Liver
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 Mast cell                 Liver
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 Mast cell                 Liver
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 Mast cell                 Liver
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 Mast cell                 Liver
#                                             Dataset             Protocol
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 Popescu et al. 2019 10X
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 Popescu et al. 2019 10X
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 Popescu et al. 2019 10X
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 Popescu et al. 2019 10X
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 Popescu et al. 2019 10X
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 Popescu et al. 2019 10X
#                                             Iteration High_hierarchy
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 1         Group49
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 1         Group49
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 1         Group49
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 1         Group49
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 1         Group49
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 1         Group49
#                                             Low_hierarchy
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 UNRESOLVED = UNRESOLVED = UNRESOLVED = UNRESOLVED = Mast cell
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 UNRESOLVED = UNRESOLVED = UNRESOLVED = UNRESOLVED = Mast cell
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 UNRESOLVED = UNRESOLVED = UNRESOLVED = UNRESOLVED = Mast cell
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 UNRESOLVED = UNRESOLVED = UNRESOLVED = UNRESOLVED = Mast cell
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 UNRESOLVED = UNRESOLVED = UNRESOLVED = UNRESOLVED = Mast cell
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 UNRESOLVED = UNRESOLVED = UNRESOLVED = UNRESOLVED = Mast cell
#                                             nCount_RNA nFeature_RNA
# FCAImmP7179363_AAGGCAGGTCCGAGTC-1-popescu19 6069       351
# FCAImmP7179363_ACACCAAGTGCAGTAG-1-popescu19 3537       297
# FCAImmP7179363_ACACCCTGTGTGGCTC-1-popescu19 4169       297
# FCAImmP7179363_ACGGAGATCCTCATTA-1-popescu19 2298       241
# FCAImmP7179363_AGAGCTTCATGTTCCC-1-popescu19 1724       227
# FCAImmP7179363_ATGCGATAGGTGATAT-1-popescu19 4985       342

# %% [markdown]
# ## FastMNN

# %%
seurat <- DietSeurat(immune, counts = FALSE, data = TRUE, scale.data = FALSE)

# %%
t_start <- Sys.time()
seurat <- RunFastMNN(SplitObject(seurat, split.by = 'Dataset'), features = rownames(seurat))
seurat <- FindNeighbors(seurat, dims = 1:50, reduction = "mnn")
t_end <- Sys.time()
seurat <- RunUMAP(seurat, reduction = "mnn", dims = 1:50, seed.use = 998)
write.table(seurat@reductions$umap@cell.embeddings, file = 'fast_mnn.csv', sep = ',', quote = FALSE, row.names = TRUE, col.names = TRUE)
print(paste0("Time elapsed: ", as.numeric(t_end - t_start, units = "secs"), ' seconds'))

# %% [markdown]
# _Due to the high demand of runtime and memory, the above commands are submitted in job queues in practice. We load the resulting embeddings and visualise it._

# %%
umaps = read.table('fast_mnn.csv', sep = ',', row.names = 1, as.is = TRUE, header = TRUE)
seurat$umap = CreateDimReducObject(embeddings = as.matrix(umaps[colnames(seurat),]), key = "UMAP_")
# Out:
# Warning message:
# “No assay specified, setting assay as RNA by default.”

# %%
DimPlot(seurat, group.by = 'Dataset')
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %% [markdown]
# # Harmony

# %%
seurat <- DietSeurat(immune, counts = FALSE, data = TRUE, scale.data = TRUE, dimreducs = 'pca')

# %%
t_start <- Sys.time()
seurat <- RunHarmony(seurat, 'Dataset')
seurat <- FindNeighbors(seurat, dims = 1:50, reduction = "harmony")
t_end <- Sys.time()
seurat <- RunUMAP(seurat, dims = 1:50, seed.use = 998, reduction = "harmony")
write.table(seurat@reductions$umap@cell.embeddings, file = 'harmony_pca.csv', sep = ',', quote = FALSE, row.names = TRUE, col.names = TRUE)
print(paste0("Time elapsed: ", as.numeric(t_end - t_start, units = "secs"), ' seconds'))

# %%
umaps = read.table('harmony_pca.csv', sep = ',', row.names = 1, as.is = TRUE, header = TRUE)
seurat$umap = CreateDimReducObject(embeddings = as.matrix(umaps[colnames(seurat),]), key = "UMAP_")
# Out:
# Warning message:
# “No assay specified, setting assay as RNA by default.”

# %%
DimPlot(seurat, group.by = 'Dataset')
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %% [markdown]
# # Seurat

# %%
seurat <- DietSeurat(seurat, counts = FALSE, data = TRUE, scale.data = FALSE)

# %%
seurat_list <- SplitObject(seurat, split.by = 'Dataset')
seurat_list <- lapply(seurat_list, ScaleData)
seurat_list <- seurat_list[c('James et al. 2020', 'Madissoon et al. 2020', 'Popescu et al. 2019', 'HCA Immune 2018', 'Dominguez Conde et al. 2022')]

# %%
t_start <- Sys.time()
anchors <- FindIntegrationAnchors(seurat_list, normalization.method = 'LogNormalize', anchor.features = rownames(seurat), scale = FALSE, dims = 1:50, reference = length(seurat_list))
seurat <- IntegrateData(anchors, normalization.method = 'LogNormalize', dims = 1:50)
seurat <- ScaleData(seurat)
seurat <- RunPCA(seurat, npcs = 50, seed.use = 998)
seurat <- FindNeighbors(seurat, dims = 1:50)
t_end <- Sys.time()
seurat <- RunUMAP(seurat, dims = 1:50, seed.use = 998)
write.table(seurat@reductions$umap@cell.embeddings, file = 'seurat_cca.csv', sep = ',', quote = FALSE, row.names = TRUE, col.names = TRUE)
print(paste0("Time elapsed: ", as.numeric(t_end - t_start, units = "secs"), ' seconds'))

# %%
umaps = read.table('seurat_cca.csv', sep = ',', row.names = 1, as.is = TRUE, header = TRUE)
seurat$umap = CreateDimReducObject(embeddings = as.matrix(umaps[colnames(seurat),]), key = "UMAP_")
# Out:
# Warning message:
# “No assay specified, setting assay as RNA by default.”

# %%
DimPlot(seurat, group.by = 'Dataset')
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title
